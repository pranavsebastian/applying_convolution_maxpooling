# %%
import cv2
import numpy as np
from scipy import misc
import matplotlib.pyplot as plt

# %%
i=misc.face()
plt.grid('False')
plt.gray()
plt.axis('off')
plt.imshow(i)
plt.show()

# %%
transformed_i1=np.copy(i)
transformed_i2=np.copy(i)

# %%
x=transformed_i1.shape[0]
y=transformed_i1.shape[1]

# %%
filter = [ [-1, -2, -1], [0, 0, 0], [1, 2, 1]]
weight=1
print(x_size)
# Out:
# 768

# %%
def transform_1(x_s,y_s):
    for x in range(1,x_s-1):
        for y in range(1,y_s-1):
            output_image=0.0
            output_image=output_image + (i[x-1 , y-1] * filter[0][0])
            output_image=output_image + (i[x , y-1] * filter[0][1])
            output_image=output_image + (i[x+1 , y-1] * filter[0][2])

            output_image=output_image + (i[x-1 , y] * filter[1][0])
            output_image=output_image + (i[x, y] * filter[1][1])
            output_image=output_image + (i[x+1 , y] * filter[1][2])

            output_image=output_image + (i[x-1 , y+1] * filter[2][0])
            output_image=output_image + (i[x , y+1] * filter[2][1])
            output_image=output_image + (i[x+1 , y+1] * filter[2][2])

            output_image=output_image*weight
            if output_image < 0:
                output_image = 0
            if output_image > 255:
                output_image = 255
            transformed_i1[x,y] = output_image
    return plt.imshow(transformed_i1)

# %%
def transform_2(x_s,y_s):
    for x in range(1,x_s-1):
        for y in range(1,y_s-1):
            img_out=0.0
            img_out = img_out + (i[x-1,y-1]* filter[0][0])
            img_out = img_out + (i[x-1,y]* filter[0][1])
            img_out = img_out + (i[x-1,y+1]* filter[0][2])

            img_out = img_out + (i[x,y-1]* filter[1][0])
            img_out = img_out + (i[x,y]* filter[1][1])
            img_out = img_out + (i[x,y+1]* filter[1][2])

            img_out = img_out + (i[x+1,y-1]* filter[2][0])
            img_out = img_out + (i[x+1,y]* filter[2][1])
            img_out = img_out + (i[x+1,y+1]* filter[2][2])
            img_out=img_out*weight
            if img_out < 0:
                img_out = 0
            if img_out > 255:
                img_out = 255
            transformed_i2[x,y] = img_out
    return plt.imshow(transformed_i2)

# %%
transform_1(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4d0f29ae4342> in <module>
# ----> 1 transform_1(x,y)
#
# <ipython-input-15-0552e171e969> in transform_1(x_s, y_s)
#      16
#      17             output_image=output_image*weight
# ---> 18             if output_image < 0:
#      19                 output_image = 0
#      20             if output_image > 255:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
transform_2(x,y)
